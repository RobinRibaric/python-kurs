# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('./merged_data5.csv')



# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('productions', axis=1), df['productions'], test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.models import Sequential


# Define the input shape
input_shape = (X_train.shape[1],)

# Create the neural network model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=input_shape))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train, y_train, validation_split=0.2, epochs=50, batch_size=32) 

# Save the history to a file
with open('output.txt', 'w') as f:
    print(history.history, file=f)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0436 - mae: 0.1398 - val_loss: 0.0162 - val_mae: 0.1054
# Epoch 2/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0257 - mae: 0.1165 - val_loss: 0.0073 - val_mae: 0.0664
# Epoch 3/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142 - mae: 0.0659 - val_loss: 0.0035 - val_mae: 0.0425
# Epoch 4/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0091 - mae: 0.0506 - val_loss: 0.0022 - val_mae: 0.0349
# Epoch 5/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0056 - mae: 0.0442 - val_loss: 0.0013 - val_mae: 0.0279
# Epoch 6/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0037 - mae: 0.0329 - val_loss: 8.0176e-04 - val_mae: 0.0207
# Epoch 7/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0025 - mae: 0.0275 - val_loss: 7.8441e-04 - val_mae: 0.0189
# Epoch 8/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0233 - val_loss: 7.7347e-04 - val_mae: 0.0177
# Epoch 9/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0016 - mae: 0.0210 - val_loss: 8.7785e-04 - val_mae: 0.0171
# Epoch 10/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0014 - mae: 0.0193 - val_loss: 8.7485e-04 - val_mae: 0.0157
# Epoch 11/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0012 - mae: 0.0183 - val_loss: 8.3921e-04 - val_mae: 0.0150
# Epoch 12/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 7.6488e-04 - val_mae: 0.0141
# Epoch 13/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0011 - mae: 0.0169 - val_loss: 7.0928e-04 - val_mae: 0.0144
# Epoch 14/50
# 10/10 [==============================] - 0s 2ms/step - loss: 9.9261e-04 - mae: 0.0162 - val_loss: 6.3491e-04 - val_mae: 0.0138
# Epoch 15/50
# 10/10 [==============================] - 0s 2ms/step - loss: 9.2736e-04 - mae: 0.0154 - val_loss: 5.7739e-04 - val_mae: 0.0134
# Epoch 16/50
# 10/10 [==============================] - 0s 2ms/step - loss: 8.9434e-04 - mae: 0.0156 - val_loss: 5.3496e-04 - val_mae: 0.0137
# Epoch 17/50
# 10/10 [==============================] - 0s 2ms/step - loss: 8.1406e-04 - mae: 0.0146 - val_loss: 5.6974e-04 - val_mae: 0.0127
# Epoch 18/50
# 10/10 [==============================] - 0s 2ms/step - loss: 7.6294e-04 - mae: 0.0142 - val_loss: 5.3977e-04 - val_mae: 0.0127
# Epoch 19/50
# 10/10 [==============================] - 0s 2ms/step - loss: 7.0342e-04 - mae: 0.0135 - val_loss: 4.9473e-04 - val_mae: 0.0125
# Epoch 20/50
# 10/10 [==============================] - 0s 2ms/step - loss: 6.8368e-04 - mae: 0.0135 - val_loss: 5.0855e-04 - val_mae: 0.0129
# Epoch 21/50
# 10/10 [==============================] - 0s 2ms/step - loss: 6.0628e-04 - mae: 0.0128 - val_loss: 4.4554e-04 - val_mae: 0.0121
# Epoch 22/50
# 10/10 [==============================] - 0s 2ms/step - loss: 5.7308e-04 - mae: 0.0127 - val_loss: 4.5316e-04 - val_mae: 0.0123
# Epoch 23/50
# 10/10 [==============================] - 0s 2ms/step - loss: 5.2448e-04 - mae: 0.0121 - val_loss: 4.0634e-04 - val_mae: 0.0116
# Epoch 24/50
# 10/10 [==============================] - 0s 2ms/step - loss: 4.8640e-04 - mae: 0.0116 - val_loss: 3.6070e-04 - val_mae: 0.0113
# Epoch 25/50
# 10/10 [==============================] - 0s 2ms/step - loss: 4.5267e-04 - mae: 0.0119 - val_loss: 3.7955e-04 - val_mae: 0.0118
# Epoch 26/50
# 10/10 [==============================] - 0s 2ms/step - loss: 4.1502e-04 - mae: 0.0112 - val_loss: 3.6133e-04 - val_mae: 0.0127
# Epoch 27/50
# 10/10 [==============================] - 0s 2ms/step - loss: 4.0307e-04 - mae: 0.0113 - val_loss: 3.3137e-04 - val_mae: 0.0115
# Epoch 28/50
# 10/10 [==============================] - 0s 2ms/step - loss: 3.5702e-04 - mae: 0.0104 - val_loss: 3.0418e-04 - val_mae: 0.0110
# Epoch 29/50
# 10/10 [==============================] - 0s 2ms/step - loss: 3.6490e-04 - mae: 0.0105 - val_loss: 2.8905e-04 - val_mae: 0.0116
# Epoch 30/50
# 10/10 [==============================] - 0s 2ms/step - loss: 3.2314e-04 - mae: 0.0108 - val_loss: 3.1741e-04 - val_mae: 0.0107
# Epoch 31/50
# 10/10 [==============================] - 0s 2ms/step - loss: 3.0988e-04 - mae: 0.0107 - val_loss: 2.8317e-04 - val_mae: 0.0111
# Epoch 32/50
# 10/10 [==============================] - 0s 2ms/step - loss: 2.9589e-04 - mae: 0.0102 - val_loss: 2.6632e-04 - val_mae: 0.0105
# Epoch 33/50
# 10/10 [==============================] - 0s 2ms/step - loss: 2.5206e-04 - mae: 0.0093 - val_loss: 2.6588e-04 - val_mae: 0.0113
# Epoch 34/50
# 10/10 [==============================] - 0s 2ms/step - loss: 2.4303e-04 - mae: 0.0095 - val_loss: 2.6789e-04 - val_mae: 0.0109
# Epoch 35/50
# 10/10 [==============================] - 0s 2ms/step - loss: 2.4727e-04 - mae: 0.0105 - val_loss: 2.3633e-04 - val_mae: 0.0112
# Epoch 36/50
# 10/10 [==============================] - 0s 2ms/step - loss: 2.2225e-04 - mae: 0.0096 - val_loss: 2.6751e-04 - val_mae: 0.0112
# Epoch 37/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8132e-04 - mae: 0.0089 - val_loss: 2.2162e-04 - val_mae: 0.0098
# Epoch 38/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8542e-04 - mae: 0.0089 - val_loss: 2.3832e-04 - val_mae: 0.0112
# Epoch 39/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7226e-04 - mae: 0.0087 - val_loss: 2.1008e-04 - val_mae: 0.0097
# Epoch 40/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6059e-04 - mae: 0.0078 - val_loss: 2.1695e-04 - val_mae: 0.0099
# Epoch 41/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6105e-04 - mae: 0.0087 - val_loss: 2.1709e-04 - val_mae: 0.0106
# Epoch 42/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4541e-04 - mae: 0.0081 - val_loss: 2.0508e-04 - val_mae: 0.0097
# Epoch 43/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2783e-04 - mae: 0.0073 - val_loss: 1.8940e-04 - val_mae: 0.0099
# Epoch 44/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2142e-04 - mae: 0.0074 - val_loss: 2.0411e-04 - val_mae: 0.0102
# Epoch 45/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1580e-04 - mae: 0.0072 - val_loss: 1.7965e-04 - val_mae: 0.0093
# Epoch 46/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1261e-04 - mae: 0.0070 - val_loss: 1.6622e-04 - val_mae: 0.0088
# Epoch 47/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1029e-04 - mae: 0.0069 - val_loss: 1.6459e-04 - val_mae: 0.0088
# Epoch 48/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0115e-04 - mae: 0.0062 - val_loss: 1.7478e-04 - val_mae: 0.0088
# Epoch 49/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3202e-04 - mae: 0.0074 - val_loss: 1.8499e-04 - val_mae: 0.0096
# Epoch 50/50
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1821e-04 - mae: 0.0074 - val_loss: 1.8268e-04 - val_mae: 0.0095

# %%
y_pred = model.predict(X_test)
y_pred
